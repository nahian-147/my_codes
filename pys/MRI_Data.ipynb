# %%
import time
import numpy as np


from skimage import io

import matplotlib.pyplot as plt

# %%
vol = io.imread("https://s3.amazonaws.com/assets.datacamp.com/blog_assets/attention-mri.tif")
volume = vol.T

# %%
np.shape(vol)
# Out:
# (157, 189, 68)

# %%
plt.imshow(vol[:,:,33])

# %%
plt.imshow(volume[33,:,:].T)
